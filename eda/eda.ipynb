# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("../data/raw/BoilerPlant.csv")
df.head(10)
# Out:
#               Datetime  BOI_FLOW_1  BOI_FLOW_2  BOI_GAS_CSUM_1  \
# 0  2018-01-01 01:00:00  364.566101     0.00068      1726.88233
# 1  2018-01-01 01:01:00  364.566101     0.00068      1726.88233
# 2  2018-01-01 01:02:00  364.566101     0.00068      1726.88233
# 3  2018-01-01 01:03:00  364.566101     0.00068      1726.88233
# 4  2018-01-01 01:04:00  364.566101     0.00068      1726.88233
# 5  2018-01-01 01:05:00  364.566101     0.00068      1726.88233
# 6  2018-01-01 01:06:00  364.566101     0.00068      1726.88233
# 7  2018-01-01 01:07:00  364.566101     0.00068      1726.88233
# 8  2018-01-01 01:08:00  364.566101     0.00068      1726.88233
# 9  2018-01-01 01:09:00  364.566101     0.00068      1726.88233
#
#    BOI_GAS_CSUM_2  BOI_RW_TEMP_1  BOI_RW_TEMP_2  BOI_STA_1  BOI_STA_2  \
# 0             0.0      99.939835      68.002411        1.0        0.0
# 1             0.0     100.435318      68.002525        1.0        0.0
# ...

# %%
df.isna().sum()
# Out:
# Datetime          0
# BOI_FLOW_1        0
# BOI_FLOW_2        0
# BOI_GAS_CSUM_1    0
# BOI_GAS_CSUM_2    0
# BOI_RW_TEMP_1     0
# BOI_RW_TEMP_2     0
# BOI_STA_1         0
# BOI_STA_2         0
# BOI_SW_TEMP_1     0
# BOI_SW_TEMP_2     0
# HWL_DP            0
# HWL_DPSPT         0
# HWL_RW_TEMP       0
# HWL_SW_TEMP       0
# OA_TEMP           0
# PM_POW_1          0
# PM_POW_2          0
# PM_SPD_1          0
# PM_SPD_2          0
# PM_STA_1          0
# PM_STA_2          0
# SEC_POW           0
# dtype: int64
